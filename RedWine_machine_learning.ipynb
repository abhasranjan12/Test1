# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv('winequality-red.csv',)

# %%
df.shape
# Out:
# (1599, 1)

# %%
df1=pd.read_csv('winequality-red.csv', delimiter=';')
df1.shape
# Out:
# (1599, 12)

# %%
df1
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# 5               7.4             0.660         0.00             1.8      0.075
# 6               7.9             0.600         0.06             1.6      0.069
# 7               7.3             0.650         0.00             1.2      0.065
# 8               7.8             0.580         0.02             2.0      0.073
# 9               7.5             0.500         0.36             6.1      0.071
# 10              6.7             0.580         0.08             1.8      0.097
# ...

# %%
df1.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
X=df1[['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'sulphates','alcohol','pH']]
y=df1[['quality']]

# %%
fig=plt.figure(figsize=(10,10))
plt.subplot(3,4,1)
plt.scatter(df1['fixed acidity'],y)
plt.subplot(3,4,2)
plt.scatter(df1['volatile acidity'],y)
plt.subplot(3,4,3)
plt.scatter(df1['citric acid'],y)
plt.subplot(3,4,4)
plt.scatter(df1['residual sugar'],y)
plt.subplot(3,4,5)
plt.scatter(df1['chlorides'],y)

plt.subplot(3,4,6)
plt.scatter(df1['free sulfur dioxide'],y)

plt.subplot(3,4,7)
plt.scatter(df1['total sulfur dioxide'],y)

plt.subplot(3,4,8)
plt.scatter(df1['density'],y)

plt.subplot(3,4,9)
plt.scatter(df1['alcohol'],y)

plt.subplot(3,4,10)
plt.scatter(df1['sulphates'],y)

plt.subplot(3,4,11)
plt.scatter(df1['quality'],y)

# %%
sns.distplot(df1['fixed acidity'],bins=50)
print('skewness: '+str(df1['fixed acidity'].skew()))
print('Kurtosis: '+str(df1['fixed acidity'].kurtosis()))
# Out:
# skewness: 0.9827514413284587
# Kurtosis: 1.1321433977276252

# %%
sns.distplot(df1['volatile acidity'],bins=50)

print('skewness: '+str(df1['volatile acidity'].skew()))
print('Kurtosis: '+str(df1['volatile acidity'].kurtosis()))
# Out:
# skewness: 0.6715925723840199
# Kurtosis: 1.2255422501791422

# %%
sns.distplot(df1['citric acid'],bins=50)

print('skewness: '+str(df1['citric acid'].skew()))
print('Kurtosis: '+str(df1['citric acid'].kurtosis()))
# Out:
# skewness: 0.3183372952546368
# Kurtosis: -0.7889975153633966

# %%
sns.distplot(df1['residual sugar'],bins=50)

print('skewness: '+str(df1['residual sugar'].skew()))
print('Kurtosis: '+str(df1['residual sugar'].kurtosis()))
df2=df1[((df1['residual sugar']>(np.mean(df1['residual sugar'])-2*np.std(df1['residual sugar'])))&(df1['residual sugar']<(np.mean(df1['residual sugar'])+2*np.std(df1['residual sugar']))))]
df2['residual sugar'].skew()
# Out:
# skewness: 4.54065542590319
# Kurtosis: 28.617595424475443
# 1.699365314184103

# %%
sns.distplot(df1['chlorides'],bins=50)

print('skewness: '+str(df1['chlorides'].skew()))
print('Kurtosis: '+str(df1['chlorides'].kurtosis()))
df2=df1[((df1['chlorides']>(np.mean(df1['chlorides'])-2*np.std(df1['chlorides'])))&(df1['chlorides']<(np.mean(df1['chlorides'])+2*np.std(df1['chlorides']))))]
df2['chlorides'].skew()
# Out:
# skewness: 5.680346571971722
# Kurtosis: 41.71578724757661
# 1.3160152382674415

# %%
sns.distplot(df1['free sulfur dioxide'],bins=50)

print('skewness: '+str(df1['free sulfur dioxide'].skew()))
print('Kurtosis: '+str(df1['free sulfur dioxide'].kurtosis()))
# Out:
# skewness: 1.250567293314441
# Kurtosis: 2.023562045840575

# %%
sns.distplot(df1['total sulfur dioxide'],bins=50)

print('skewness: '+str(df1['total sulfur dioxide'].skew()))
print('Kurtosis: '+str(df1['total sulfur dioxide'].kurtosis()))
# Out:
# skewness: 1.515531257594554
# Kurtosis: 3.8098244878645744

# %%
sns.distplot(df1['density'],bins=50)

print('skewness: '+str(df1['density'].skew()))
print('Kurtosis: '+str(df1['density'].kurtosis()))
# Out:
# skewness: 0.07128766294945525
# Kurtosis: 0.9340790654648083

# %%
sns.distplot(df1['pH'],bins=50)

print('skewness: '+str(df1['pH'].skew()))
print('Kurtosis: '+str(df1['pH'].kurtosis()))
# Out:
# skewness: 0.19368349811284427
# Kurtosis: 0.806942508246574

# %%
sns.distplot(df1['quality'],bins=50)

print('skewness: '+str(df1['quality'].skew()))
print('Kurtosis: '+str(df1['quality'].kurtosis()))
# Out:
# skewness: 0.21780157547366327
# Kurtosis: 0.2967081197538759

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df2.corr(),annot=True)

# %% [markdown]
# # split the data

# %%
from sklearn.model_selection import train_test_split

# %%
df_train,df_test=train_test_split(df2,test_size=0.3,random_state=101)

# %% [markdown]
# # scaling

# %%
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings('ignore')

# %%
sc=StandardScaler()

# %%
df_train_scaled=pd.DataFrame(sc.fit_transform(df_train),columns=df2.columns)
df_train_scaled.shape
# Out:
# (1087, 12)

# %%
df_test_scaled=pd.DataFrame(sc.fit_transform(df_test),columns=df2.columns)
df_test_scaled.shape
# Out:
# (467, 12)

# %%
X_train=df_train_scaled.drop("quality",axis=1)
X_test=df_test_scaled.drop("quality",axis=1)

# %%
y_train=df_train_scaled['quality']
y_test=df_test_scaled['quality']

# %% [markdown]
# # RFE

# %%
from sklearn.feature_selection import RFE

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
rfe=RFE(lr,9)
rfe=rfe.fit(X_train,y_train)
rfe.support_
rfe.ranking_
# Out:
# array([1, 1, 1, 3, 1, 2, 1, 1, 1, 1, 1])

# %%
list(zip(X_train.columns,rfe.support_,rfe.ranking_))
# Out:
# [('fixed acidity', True, 1),
#  ('volatile acidity', True, 1),
#  ('citric acid', True, 1),
#  ('residual sugar', False, 3),
#  ('chlorides', True, 1),
#  ('free sulfur dioxide', False, 2),
#  ('total sulfur dioxide', True, 1),
#  ('density', True, 1),
#  ('pH', True, 1),
#  ('sulphates', True, 1),
#  ('alcohol', True, 1)]

# %%
selected_col=X_train.columns[rfe.support_]
selected_col
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'chlorides',
#        'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol'],
#       dtype='object')

# %%
X_train_rfe=X_train[selected_col]

# %%
import statsmodels.api as sm

# %%
X_train_scale_sm=sm.add_constant(X_train)
lr1=sm.OLS(y_train,X_train_scale_sm).fit()

# %%
X_test_scale_sm=sm.add_constant(X_test)
lr1=sm.OLS(y_train,X_train_scale_sm).fit()

# %%
lr1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7506b60f72ed> in <module>
# ----> 1 lr1
#
# NameError: name 'lr1' is not defined

# %%
X_train_scale_sm
# Out:
#       const  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0       1.0      -0.929290          0.854278    -1.050129       -0.096768
# 1       1.0       0.416066         -1.323012     0.299089       -0.370590
# 2       1.0      -1.041403          0.826001    -1.413381        1.389694
# 3       1.0      -0.873234          0.882554    -0.946343        1.076755
# 4       1.0       0.023671         -0.022293    -0.271734        0.137937
# 5       1.0      -1.545912          0.090813    -1.205809       -0.644412
# 6       1.0       0.640292         -0.361611    -0.167948        0.137937
# 7       1.0      -0.985347          0.599789    -1.413381        1.389694
# 8       1.0      -0.200556          0.373578    -0.583092       -0.566177
# 9       1.0      -0.536895          0.486684    -1.361488       -0.409707
# 10      1.0      -1.041403         -0.078846    -0.634985        0.372641
# 11      1.0       0.079727         -0.305058    -0.012269       -0.487942
# ...

# %%
print(lr1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                quality   R-squared:                       0.353
# Model:                            OLS   Adj. R-squared:                  0.347
# Method:                 Least Squares   F-statistic:                     53.41
# Date:                Wed, 25 Sep 2019   Prob (F-statistic):           6.00e-94
# Time:                        14:26:10   Log-Likelihood:                -1305.4
# No. Observations:                1087   AIC:                             2635.
# Df Residuals:                    1075   BIC:                             2695.
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                 3.756e-15      0.025   1.53e-13      1.000      -0.048       0.048
# ...

# %% [markdown]
# # train models

# %%
lr.fit(X_train_scale_sm,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
lr.intercept_
# Out:
# 3.7420999764503356e-15

# %%
lr.coef_
# Out:
# array([ 0.        ,  0.07864256, -0.21916093, -0.05700431, -0.00244767,
#        -0.0583208 ,  0.0311754 , -0.10532393, -0.05780903, -0.05863194,
#         0.17959   ,  0.36545888])

# %%
from sklearn import metrics

# %%
y_pred=lr.predict(X_test_scale_sm)
y_pred_train=lr.predict(X_train_scale_sm)

# %%
metrics.r2_score(y_test,y_pred)
# Out:
# 0.3790177885849083

# %%
X_train_scale_sm=sm.add_constant(X_test)
lr1=sm.OLS(y_test,X_test_scale_sm).fit()

# %%
print(lr1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                quality   R-squared:                       0.404
# Model:                            OLS   Adj. R-squared:                  0.390
# Method:                 Least Squares   F-statistic:                     28.06
# Date:                Wed, 25 Sep 2019   Prob (F-statistic):           9.80e-45
# Time:                        14:26:13   Log-Likelihood:                -541.73
# No. Observations:                 467   AIC:                             1107.
# Df Residuals:                     455   BIC:                             1157.
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                -9.825e-16      0.036  -2.72e-14      1.000      -0.071       0.071
# ...

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=2)
knn.fit(X_train,y_train)
y_pred=knn.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-115-9f4fcc81b4ee> in <module>
#       1 from sklearn.neighbors import KNeighborsClassifier
#       2 knn=KNeighborsClassifier(n_neighbors=2)
# ----> 3 knn.fit(X_train,y_train)
#       4 y_pred=knn.predict(x_test)
#
# ~\Anaconda3\lib\site-packages\sklearn\neighbors\base.py in fit(self, X, y)
#     903             self.outputs_2d_ = True
#     904
# --> 905         check_classification_targets(y)
#     906         self.classes_ = []
#     907         self._y = np.empty(y.shape, dtype=np.int)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\multiclass.py in check_classification_targets(y)
#     169     if y_type not in ['binary', 'multiclass', 'multiclass-multioutput',
#     170                       'multilabel-indicator', 'multilabel-sequences']:
# --> 171         raise ValueError("Unknown label type: %r" % y_type)
# ...

# %%
y=df1['quality']
X=df1.drop(['quality'],axis=1)

# %%
X_scaled=sc.fit_transform(X)

# %%
X_train,X_test,y_train,y_test=train_test_split(X_scaled,y,test_size=0.3,random_state=101)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train,y_train)
y_pred=knn.predict(X_test)
from sklearn.metrics import classification_report, confusion_matrix,accuracy_score
print(metrics.classification_report(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         5
#            4       0.00      0.00      0.00        19
#            5       0.68      0.69      0.68       208
#            6       0.53      0.61      0.57       180
#            7       0.45      0.41      0.43        63
#            8       0.00      0.00      0.00         5
#
#    micro avg       0.58      0.58      0.58       480
#    macro avg       0.28      0.28      0.28       480
# weighted avg       0.55      0.58      0.56       480
#
# [[  0   1   1   3   0   0]
#  [  0   0  12   7   0   0]
#  [  0   4 143  56   5   0]
#  [  0   1  46 109  24   0]
#  [  0   0   9  28  26   0]
#  [  0   0   0   2   3   0]]

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 0.5791666666666667
